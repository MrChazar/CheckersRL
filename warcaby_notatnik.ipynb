# %% [markdown]
# # Podpięcie swojego dysku

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Wykonanie kroków do builda projektu z ich ([repo](https://github.com/EndlessLethe/DeepDraughts)) opisane w README

# %%
# %cd drive/MyDrive/rl-stuff/resources # tutaj trzeba podać swoją ściezkę do folderu 'resources'

# %%
# !unzip endgame.zip
# Out:
# Archive:  endgame.zip
#   inflating: endgame2p.pkl
#   inflating: endgame3p.pkl
#   inflating: endgame4p.pkl
#   inflating: endgame1p.pkl

# %%
# %cd ..
# Out:
# /

# %%
# %%python setup.py build
# %%python setup.py install
# Out:
# running build
# running build_py
# creating build/lib/deepdraughts
# copying deepdraughts/gui.py -> build/lib/deepdraughts
# copying deepdraughts/net_pytorch.py -> build/lib/deepdraughts
# copying deepdraughts/__init__.py -> build/lib/deepdraughts
# copying deepdraughts/train_pipline.py -> build/lib/deepdraughts
# copying deepdraughts/mcts_alphazero.py -> build/lib/deepdraughts
# copying deepdraughts/mcts_pure.py -> build/lib/deepdraughts
# copying deepdraughts/game_collector.py -> build/lib/deepdraughts
# creating build/lib/deepdraughts/env
# copying deepdraughts/env/__init__.py -> build/lib/deepdraughts/env
# creating build/lib/deepdraughts/endgame
# copying deepdraughts/endgame/__init__.py -> build/lib/deepdraughts/endgame
# copying deepdraughts/endgame/generator.py -> build/lib/deepdraughts/endgame
# creating build/lib/deepdraughts/env/cython_env
# copying deepdraughts/env/cython_env/env_utils.py -> build/lib/deepdraughts/env/cython_env
# ...

# %% [markdown]
# # Import modułów zapisanych na dysku

# %%
import sys
sys.path.insert(0, "/content/drive/MyDrive/rl-stuff/deepdraughts/env")

# %%
import py_env.game as g
import py_env.env_utils as utils

# %%
game = g.Game(rule = utils.RUSSIAN_RULE)

# %%
moves = game.get_all_available_moves()
for move in moves:
  print(move)
# Out:
# 40-33
# 42-33
# 42-35
# 44-35
# 44-37
# 46-37
# 46-39

# %%
fen = game.to_fen()

# %%
print(fen)
# Out:
# W:WA3,C3,E3,G3,B2,D2,F2,H2,A1,C1,E1,G1:BB8,D8,F8,H8,A7,C7,E7,G7,B6,D6,F6,H6.
